# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# min_YCrCb = np.array([0,133,77],np.uint8)
# max_YCrCb = np.array([235,173,127],np.uint8)

min_YCrCb = np.array([40,130,100],np.uint8)
max_YCrCb = np.array([160,160,120],np.uint8)

# Get pointer to video frames from primary device
# image2 = cv2.imread("D:/VA/31words_DSLR/boot/shruti295.jpg")
image2 = cv2.imread("D:/VA/31words_DSLR/boot/agrima75.jpg")
imageYCrCb = cv2.cvtColor(image2,cv2.COLOR_BGR2YCR_CB)
skinRegionYCrCb = cv2.inRange(imageYCrCb,min_YCrCb,max_YCrCb)

skinYCrCb = cv2.bitwise_and(image2, image2, mask = skinRegionYCrCb)

# cv2.imwrite("/assets/img/skin-detection/ycrcb.png", np.hstack([image2,skinYCrCb]))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,8), sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(cv2.cvtColor(image2,cv2.COLOR_BGR2RGB))
ax1.set_title('Input image')

# Rescale histogram for better display

# display the HOG features
ax2.axis('off')
ax2.imshow(cv2.cvtColor(skinYCrCb,cv2.COLOR_BGR2RGB))
ax2.set_title('Histogram of Oriented Gradients')
# Out:
# Text(0.5, 1.0, 'Histogram of Oriented Gradients')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# min_YCrCb = np.array([0,133,77],np.uint8)
# max_YCrCb = np.array([235,173,127],np.uint8)

min_YCrCb = np.array([0,133,77],np.uint8)
max_YCrCb = np.array([255,173,127],np.uint8)

# Get pointer to video frames from primary device
# image2 = cv2.imread("D:/VA/31words_DSLR/boot/shruti295.jpg")
image2 = cv2.imread("D:/VA/31words_DSLR/boot/rajesh310.jpg")
imageYCrCb = cv2.cvtColor(image2,cv2.COLOR_BGR2YCR_CB)
skinRegionYCrCb = cv2.inRange(imageYCrCb,min_YCrCb,max_YCrCb)

skinYCrCb = cv2.bitwise_and(image2, image2, mask = skinRegionYCrCb)

# cv2.imwrite("/assets/img/skin-detection/ycrcb.png", np.hstack([image2,skinYCrCb]))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,8), sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(cv2.cvtColor(image2,cv2.COLOR_BGR2RGB))
ax1.set_title('Input image')

# Rescale histogram for better display

# display the HOG features
ax2.axis('off')
ax2.imshow(cv2.cvtColor(skinYCrCb,cv2.COLOR_BGR2RGB))
ax2.set_title('Histogram of Oriented Gradients')
# Out:
# Text(0.5, 1.0, 'Histogram of Oriented Gradients')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# min_YCrCb = np.array([0,133,77],np.uint8)
# max_YCrCb = np.array([235,173,127],np.uint8)

min_YCrCb = np.array([0,133,77],np.uint8)
max_YCrCb = np.array([255,173,127],np.uint8)

# Get pointer to video frames from primary device
image2 = cv2.imread("D:/VA/31words_DSLR/boot/shruti295.jpg")
# image2 = cv2.imread("D:/VA/31words_DSLR/boot/rajesh310.jpg")
imageYCrCb = cv2.cvtColor(image2,cv2.COLOR_BGR2YCR_CB)
skinRegionYCrCb = cv2.inRange(imageYCrCb,min_YCrCb,max_YCrCb)

skinYCrCb = cv2.bitwise_and(image2, image2, mask = skinRegionYCrCb)

# cv2.imwrite("/assets/img/skin-detection/ycrcb.png", np.hstack([image2,skinYCrCb]))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,8), sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(cv2.cvtColor(image2,cv2.COLOR_BGR2RGB))
ax1.set_title('Input image')

# Rescale histogram for better display

# display the HOG features
ax2.axis('off')
ax2.imshow(cv2.cvtColor(skinYCrCb,cv2.COLOR_BGR2RGB))
ax2.set_title('Histogram of Oriented Gradients')
# thresh = cv2.adaptiveThreshold(skinYCrCb, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 21, 25)
# plt.imshow(thresh)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 32
#      30 ax2.imshow(cv2.cvtColor(skinYCrCb,cv2.COLOR_BGR2RGB))
#      31 ax2.set_title('Histogram of Oriented Gradients')
# ---> 32 thresh = cv2.adaptiveThreshold(skinYCrCb, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 21, 25)
#      33 ax2.imshow(thresh)
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\thresh.cpp:1674: error: (-215:Assertion failed) src.type() == CV_8UC1 in function 'cv::adaptiveThreshold'

# %%
gray = cv2.cvtColor(skinYCrCb, cv2.COLOR_BGR2GRAY)
thresh = cv2.adaptiveThreshold(gray, 255,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV, 21, 10)
cv2.imshow("Otsu Thresholding", threshInv)
cv2.waitKey(0)
# Out:
# -1

# %%
data = skinYCrCb
arrReshaped = data.reshape(data.shape[0], -1)
# saving reshaped array to file.
np.savetxt("D:/VA/file.csv", arrReshaped)

# %%
(R,G,B)=(113,58,33)
Y =   16 +  65.738*R/256 + 129.057*G/256 +  25.064*B/256
Cb = 128 -  37.945*R/256 -  74.494*G/256 + 112.439*B/256
Cr = 128 + 112.439*R/256 -  94.154*G/256 -  18.285*B/256
print(Y,Cr,Cb)
# Out:
# 77.487546875 153.94246093750002 108.86738281250001

# %%
(R,G,B)=(200,148,114)
Y =   16 +  65.738*R/256 + 129.057*G/256 +  25.064*B/256
Cb = 128 -  37.945*R/256 -  74.494*G/256 + 112.439*B/256
Cr = 128 + 112.439*R/256 -  94.154*G/256 -  18.285*B/256
print(Y,Cr,Cb)
# Out:
# 153.13020312499998 153.26764843750001 105.3591171875

# %%
(R,G,B)=(60,28,13)
Y =   16 +  65.738*R/256 + 129.057*G/256 +  25.064*B/256
Cb = 128 -  37.945*R/256 -  74.494*G/256 + 112.439*B/256
Cr = 128 + 112.439*R/256 -  94.154*G/256 -  18.285*B/256
print(Y,Cr,Cb)
# Out:
# 46.795734375 143.12626171875 116.66865234375
