# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
from sklearn.model_selection import train_test_split
import cv2
from tqdm import tqdm
import os
import matplotlib.pyplot as plt
#https://arxiv.org/pdf/2204.11024v1.pdf

# %%
TRAIN_DIR = "F:/VA/106words"
MASK_DIR = "F:/VA/106words_hog"
CATEGORIES = []
for img in tqdm(os.listdir(TRAIN_DIR)):
    CATEGORIES.append(img)
#print(CATEGORIES)
cat_len=len(CATEGORIES)
print(cat_len)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 106/106 [00:00<?, ?it/s]
# 106

# %%
for category in CATEGORIES:
    try: 
        os.makedirs(os.path.join(MASK_DIR, category))
    except:
        pass

# %%
from skimage.feature import hog
import matplotlib.pyplot as plt
#importing required libraries
from skimage.io import imread
from skimage.transform import resize
from skimage.feature import hog
from skimage import exposure
import matplotlib.pyplot as plt

training_data = []
training_data1 = []

for category in CATEGORIES:
    path=TRAIN_DIR+"/"+category
    path2=MASK_DIR+"/"+category
    
    class_num = CATEGORIES.index(category)
    for c_img in tqdm(os.listdir(path)):
        img_array = plt.imread((path+"/"+c_img))
        fd, hog_image = hog(img_array, orientations=9, pixels_per_cell=(4,4),
                    cells_per_block=(4,4), visualize=True, block_norm="L2", channel_axis=-1)
#         img = exposure.rescale_intensity(hog_image, in_range=(1, 10))

        img = cv2.resize(hog_image, (224, 224))
#         img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#         imagem = cv2.bitwise_not(img)
#             cv2.imshow('m',img)
#             key = cv2.waitKey(500)
#             cv2.destroyAllWindows()
        plt.imsave((path2+"/"+c_img),img, cmap="gray")
        training_data.append([img, class_num])  
random.shuffle(training_data)
# Out:
#   8%|██████▉                                                                          | 34/400 [00:46<08:22,  1.37s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 20
#      18     for c_img in tqdm(os.listdir(path)):
#      19         img_array = plt.imread((path+"/"+c_img))
# ---> 20         fd, hog_image = hog(img_array, orientations=9, pixels_per_cell=(4,4),
#      21                     cells_per_block=(4,4), visualize=True, block_norm="L2", channel_axis=-1)
#      22 #         img = exposure.rescale_intensity(hog_image, in_range=(1, 10))
#      24         img = cv2.resize(hog_image, (224, 224))
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\skimage\_shared\utils.py:338, in channel_as_last_axis.__call__.<locals>.fixed_func(*args, **kwargs)
#     334     raise ValueError(
# ...

# %%
print(img)
# Out:
# [[0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [2.45551238e-04 4.22701247e-03 3.97554061e-04 ... 0.00000000e+00
#   1.20729119e-03 0.00000000e+00]
#  [0.00000000e+00 6.20825142e-05 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 2.79383261e-03 4.33254756e-05 ... 0.00000000e+00
#   2.58901540e-04 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]]

# %%
from skimage.feature import hog
import matplotlib.pyplot as plt
#importing required libraries
from skimage.io import imread
from skimage.transform import resize
from skimage.feature import hog
from skimage import exposure
import matplotlib.pyplot as plt
file2  = "D:/VA/31words_DSLR/boot/agrima75.jpg"
image2 = plt.imread(file2)

# fd, hog_image = hog(image2, orientations=2, pixels_per_cell=(4, 4),
#                     cells_per_block=(4, 4), visualize=True, block_norm="L1", transform_sqrt=False, multichannel=True)

fd, hog_image = hog(image2, orientations=9, pixels_per_cell=(8,8),
                    cells_per_block=(2,2), visualize=True, block_norm="L1", channel_axis=-1)

# display the image
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4), sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(image2, cmap=plt.cm.gray)
ax1.set_title('Input image')

# Rescale histogram for better display
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))
# display the HOG features
ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)
ax2.set_title('Histogram of Oriented Gradients')
# Out:
# Text(0.5, 1.0, 'Histogram of Oriented Gradients')

# %%
from skimage.feature import hog
import matplotlib.pyplot as plt
file2  = "D:/VA/31words_DSLR/boot/shruti295.jpg"
image2 = plt.imread(file2)

# fd, hog_image = hog(image2, orientations=2, pixels_per_cell=(4, 4),
#                     cells_per_block=(4, 4), visualize=True, block_norm="L1", transform_sqrt=False, multichannel=True)

fd, hog_image = hog(image2, orientations=9, pixels_per_cell=(8,8),
                    cells_per_block=(2,2), visualize=True, block_norm="L1", channel_axis=-1)

# display the image
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4), sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(image2, cmap=plt.cm.gray)
ax1.set_title('Input image')

# Rescale histogram for better display
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))
# display the HOG features
ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)
ax2.set_title('Histogram of Oriented Gradients')
# Out:
# Text(0.5, 1.0, 'Histogram of Oriented Gradients')

# %%
from skimage.feature import hog
import matplotlib.pyplot as plt
file2  = "D:/VA/31words_DSLR/keep/agrima75.jpg"
image2 = plt.imread(file2)

# fd, hog_image = hog(image2, orientations=2, pixels_per_cell=(4, 4),
#                     cells_per_block=(4, 4), visualize=True, block_norm="L1", transform_sqrt=False, multichannel=True)

fd, hog_image = hog(image2, orientations=9, pixels_per_cell=(8,8),
                    cells_per_block=(2,2), visualize=True, block_norm="L1", channel_axis=-1)

# display the image
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4), sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(image2, cmap=plt.cm.gray)
ax1.set_title('Input image')

# Rescale histogram for better display
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))
# display the HOG features
ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)
ax2.set_title('Histogram of Oriented Gradients')
# Out:
# Text(0.5, 1.0, 'Histogram of Oriented Gradients')

# %%
from skimage.feature import hog
import matplotlib.pyplot as plt
file2  = "D:/VA/31words_DSLR/boot/shruti295.jpg"
image2 = cv2.imread(file2, cv2.IMREAD_GRAYSCALE)
orb = cv2.ORB_create(nfeatures=1000)
keypoints_orb, descriptors = orb.detectAndCompute(image2, None)
# fd, hog_image = hog(image2, orientations=2, pixels_per_cell=(4, 4),
#                     cells_per_block=(4, 4), visualize=True, block_norm="L1", transform_sqrt=False, multichannel=True)
img = cv2.drawKeypoints(image2, keypoints_orb, None)

cv2.imshow("Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from skimage.feature import hog
import matplotlib.pyplot as plt
file2  = "D:/VA/31words_DSLR/boot/shruti295.jpg"
image2 = cv2.imread(file2, cv2.IMREAD_GRAYSCALE)
sift = cv2.xfeatures2d.SIFT_create()
keypoints_sift, descriptors = sift.detectAndCompute(image2, None)
# fd, hog_image = hog(image2, orientations=2, pixels_per_cell=(4, 4),
#                     cells_per_block=(4, 4), visualize=True, block_norm="L1", transform_sqrt=False, multichannel=True)
img = cv2.drawKeypoints(image2, keypoints_sift, None)

cv2.imshow("Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
load_path='E:/VA/onehandtwohand/128/106words_DSLR_FH/'
CATEGORIES=np.load(load_path+'cat_106.npy', allow_pickle=True)
IMG_SIZE=128
cat_len=len(CATEGORIES)
print(cat_len)
X=np.load(load_path+'X_dslr.npy', allow_pickle=True)
Y=np.load(load_path+'Y_dslr.npy', allow_pickle=True)
# X = X.astype('float32')
# X /= 255
# Out:
# 106

# %%
Y_new=[]
for i in range(len(X)):
    index = (Y[i].tolist()).index(1)
    Y_new.append(index)
len(Y_new)

Y=np.array(Y_new)
print(Y.shape)
# Out:
# (43469,)
