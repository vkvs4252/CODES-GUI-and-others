# %%
import keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D, Dropout, BatchNormalization, Dense, Flatten, LayerNormalization
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam
import tensorflow.keras.applications as appl
from sklearn.model_selection import train_test_split
import os
import cv2
import time
import random
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.metrics as metrics
from tqdm import tqdm
from tensorflow.keras.utils import Sequence
from keras import callbacks  
from keras.models import load_model
from keras.utils import np_utils

# %%
load_path='E:/VA/onehandtwohand/128/106words_DSLR_FH/'

# %%
CATEGORIES=np.load(load_path+'cat_106.npy', allow_pickle=True)

# %%
IMG_SIZE=128

# %%
cat_len=len(CATEGORIES)
print(cat_len)
# Out:
# 106

# %% [markdown]
# # Save combined data npy

# %%
# model

# model_name1 = 'InceptionResNetV2'
# model_name1 = '4layer'
model_name1 = '15layer_lr0.00001_106words_dslr128-99.80'
#model_name2 = 'VGG16'
# model_name1 = 'DenseNet121'
# model_name1 = 'InceptionV3'

# %% [markdown]
# Loading

# %%
X=np.load(load_path+'X_dslr.npy', allow_pickle=True)
Y=np.load(load_path+'Y_dslr.npy', allow_pickle=True)

# %%
X = X.astype('float32')
X /= 255

# %%
print('Splitting') 
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state = cat_len)
X_train, X_new, y_train, y_new = train_test_split(X_train, y_train, test_size = 0.2, random_state = cat_len)
X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)
X_new = np.array(X_new)
y_new = np.array(y_new)

print("pass")
# Out:
# Splitting
# pass

# %%
del X,Y

# %%
print('Image Data Augmentation')
from keras.preprocessing.image import ImageDataGenerator
val_generator = ImageDataGenerator(rotation_range=0, zoom_range=0.2, width_shift_range=0.2,
    height_shift_range=0.2, shear_range=0.2)
#                                     , horizontal_flip=True, brightness_range=[0.6,1.3])
val_generator.fit(X_train)
val_generator.fit(X_new)
val_generator.fit(X_test)

print("done")
# Out:
# Image Data Augmentation
# done

# %%
#layers:15
#change:added batchnorm:+5, layernorm: +`1,learning_rate=0.00001
# # output: valacc:  acc:  %, val_loss:

model = Sequential()

model.add(Conv2D(32, (5, 5), input_shape = (IMG_SIZE,IMG_SIZE,3), padding='same', activation='relu'))         #1
# model.add(MaxPool2D(pool_size = (2, 2),strides=2,padding='same'))
# model.add(Dropout(0.30))

model.add(BatchNormalization())

model.add(Conv2D(32, (5, 5), padding='same', activation='relu'))                                              #2
# model.add(MaxPool2D(pool_size = (2, 2),strides=2,padding='same'))
# model.add(Dropout(0.30))


model.add(Conv2D(64, (5, 5), padding='same', activation='relu'))                                              #2
model.add(MaxPool2D(pool_size = (2, 2),strides=2,padding='same'))
# model.add(Dropout(0.30))

model.add(BatchNormalization())

model.add(Conv2D(64, (5, 5), padding='same', activation='relu'))                                              #2
# model.add(MaxPool2D(pool_size = (2, 2),strides=2,padding='same'))
# model.add(Dropout(0.30))

model.add(Conv2D(128, (5, 5), padding='same', activation='relu'))                                              #3
# model.add(MaxPool2D(pool_size = (2, 2),strides=2,padding='same'))
# model.add(Dropout(0.30))

model.add(BatchNormalization())

model.add(Conv2D(128, (5, 5), padding='same', activation='relu'))                                              #4
model.add(MaxPool2D(pool_size = (2, 2),strides=2,padding='same'))
# model.add(Dropout(0.30))

model.add(Conv2D(256, (5, 5), padding='same', activation='relu'))                                              #5
# model.add(MaxPool2D(pool_size = (2, 2),strides=2,padding='same'))
# model.add(Dropout(0.30))

model.add(BatchNormalization())

model.add(Conv2D(512, (5, 5), padding='same', activation='relu'))                                              #6
# model.add(MaxPool2D(pool_size = (2, 2),strides=2,padding='same'))
# model.add(Dropout(0.30))

model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))                                             #7
model.add(MaxPool2D(pool_size = (2, 2),strides=2,padding='same'))
# model.add(Dropout(0.20))

model.add(BatchNormalization())

model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))                                             #8
# model.add(MaxPool2D(pool_size = (2, 2),strides=2,padding='same'))
# model.add(Dropout(0.30))

model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))                                              #2
# model.add(MaxPool2D(pool_size = (2, 2),strides=2,padding='same'))
# model.add(Dropout(0.30))

# model.add(LayerNormalization())

model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))                                              #2
model.add(MaxPool2D(pool_size = (2, 2),strides=2,padding='same'))
# model.add(Dropout(0.30))

model.add(Flatten())

# model.add(Dense(2048, activation = 'relu'))
# model.add(Dropout(0.80))
# model.add(Dense(1024, activation = 'relu'))
# model.add(Dropout(0.80))
model.add(Dense(cat_len, activation = 'softmax'))                                               #11

model1=model
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      2432
#
#  batch_normalization (BatchN  (None, 128, 128, 32)     128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)      25632
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 64)      51264
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 64)       0
#  )
#
#  batch_normalization_1 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 64)        102464
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 128)       204928
#
#  batch_normalization_2 (Batc  (None, 64, 64, 128)      512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 128)       409728
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 128)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 256)       819456
#
#  batch_normalization_3 (Batc  (None, 32, 32, 256)      1024
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 512)       3277312
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 256)       1179904
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 256)      0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 128)       295040
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 64)        73792
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 32)        18464
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 106)               217194
#
# =================================================================
# Total params: 6,680,554
# Trainable params: 6,679,082
# Non-trainable params: 1,472
# _________________________________________________________________

# %%
print('Training model 1')
opt = Adam(learning_rate=0.00001)
earlystopping = callbacks.EarlyStopping(monitor="val_loss", patience = 10, restore_best_weights = True)
model1.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])
# model1.summary()



history_const = model1.fit(X_train, y_train,batch_size=50, epochs = 1000, validation_data=(X_test,y_test),
                   callbacks= [earlystopping])
# Out:
# Training model 1
# Epoch 1/1000
# 487/487 [==============================] - 66s 117ms/step - loss: 2.9740 - accuracy: 0.3789 - val_loss: 4.1258 - val_accuracy: 0.1033
# Epoch 2/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 1.0448 - accuracy: 0.8036 - val_loss: 0.7853 - val_accuracy: 0.8634
# Epoch 3/1000
# 487/487 [==============================] - 48s 99ms/step - loss: 0.3987 - accuracy: 0.9434 - val_loss: 0.3847 - val_accuracy: 0.9370
# Epoch 4/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 0.1643 - accuracy: 0.9857 - val_loss: 0.2147 - val_accuracy: 0.9698
# Epoch 5/1000
# 487/487 [==============================] - 48s 100ms/step - loss: 0.0728 - accuracy: 0.9972 - val_loss: 0.1374 - val_accuracy: 0.9796
# Epoch 6/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 0.0354 - accuracy: 0.9995 - val_loss: 0.1036 - val_accuracy: 0.9841
# Epoch 7/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.0792 - val_accuracy: 0.9875
# Epoch 8/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.0681 - val_accuracy: 0.9890
# Epoch 9/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.0600 - val_accuracy: 0.9896
# Epoch 10/1000
# 487/487 [==============================] - 49s 101ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0504 - val_accuracy: 0.9911
# Epoch 11/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0457 - val_accuracy: 0.9908
# Epoch 12/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 0.9915
# Epoch 13/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0379 - val_accuracy: 0.9923
# Epoch 14/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0348 - val_accuracy: 0.9919
# Epoch 15/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0324 - val_accuracy: 0.9926
# Epoch 16/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 9.4715e-04 - accuracy: 1.0000 - val_loss: 0.0294 - val_accuracy: 0.9931
# Epoch 17/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 7.1532e-04 - accuracy: 1.0000 - val_loss: 0.0276 - val_accuracy: 0.9933
# Epoch 18/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 5.3817e-04 - accuracy: 1.0000 - val_loss: 0.0259 - val_accuracy: 0.9936
# Epoch 19/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 4.0670e-04 - accuracy: 1.0000 - val_loss: 0.0239 - val_accuracy: 0.9943
# Epoch 20/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 3.1009e-04 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 0.9941
# Epoch 21/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 2.3461e-04 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9945
# Epoch 22/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 1.7848e-04 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 0.9951
# Epoch 23/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 1.3492e-04 - accuracy: 1.0000 - val_loss: 0.0192 - val_accuracy: 0.9948
# Epoch 24/1000
# 487/487 [==============================] - 49s 101ms/step - loss: 1.0302e-04 - accuracy: 1.0000 - val_loss: 0.0176 - val_accuracy: 0.9952
# Epoch 25/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 7.8060e-05 - accuracy: 1.0000 - val_loss: 0.0167 - val_accuracy: 0.9956
# Epoch 26/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 5.9801e-05 - accuracy: 1.0000 - val_loss: 0.0161 - val_accuracy: 0.9959
# Epoch 27/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 4.5119e-05 - accuracy: 1.0000 - val_loss: 0.0152 - val_accuracy: 0.9962
# Epoch 28/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 3.4699e-05 - accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 0.9962
# Epoch 29/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 2.6296e-05 - accuracy: 1.0000 - val_loss: 0.0141 - val_accuracy: 0.9961
# Epoch 30/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 2.0039e-05 - accuracy: 1.0000 - val_loss: 0.0140 - val_accuracy: 0.9965
# Epoch 31/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 1.5364e-05 - accuracy: 1.0000 - val_loss: 0.0132 - val_accuracy: 0.9968
# Epoch 32/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 1.1772e-05 - accuracy: 1.0000 - val_loss: 0.0130 - val_accuracy: 0.9967
# Epoch 33/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 8.8901e-06 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 0.9969
# Epoch 34/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 6.8233e-06 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 0.9969
# Epoch 35/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 5.2476e-06 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 0.9968
# Epoch 36/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 3.9620e-06 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 0.9971
# Epoch 37/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 3.0384e-06 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 0.9971
# Epoch 38/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 2.3364e-06 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9972
# Epoch 39/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 1.8010e-06 - accuracy: 1.0000 - val_loss: 0.0107 - val_accuracy: 0.9973
# Epoch 40/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 1.3806e-06 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 0.9971
# Epoch 41/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 1.0613e-06 - accuracy: 1.0000 - val_loss: 0.0100 - val_accuracy: 0.9973
# Epoch 42/1000
# 487/487 [==============================] - 49s 101ms/step - loss: 8.1854e-07 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9974
# Epoch 43/1000
# 487/487 [==============================] - 49s 101ms/step - loss: 6.3237e-07 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 0.9975
# Epoch 44/1000
# 487/487 [==============================] - 49s 101ms/step - loss: 4.9243e-07 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 0.9975
# Epoch 45/1000
# 487/487 [==============================] - 49s 101ms/step - loss: 3.7971e-07 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 0.9975
# Epoch 46/1000
# 487/487 [==============================] - 49s 101ms/step - loss: 2.9738e-07 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 0.9975
# Epoch 47/1000
# 487/487 [==============================] - 49s 101ms/step - loss: 2.3842e-07 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 0.9977
# Epoch 48/1000
# 487/487 [==============================] - 49s 102ms/step - loss: 1.8478e-07 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 0.9978
# Epoch 49/1000
# 487/487 [==============================] - 50s 103ms/step - loss: 1.5234e-07 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 0.9975
# Epoch 50/1000
# 487/487 [==============================] - 50s 102ms/step - loss: 1.2313e-07 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9977
# Epoch 51/1000
# 487/487 [==============================] - 49s 101ms/step - loss: 1.0130e-07 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 0.9976
# Epoch 52/1000
# 487/487 [==============================] - 49s 102ms/step - loss: 8.8190e-08 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9977
# Epoch 53/1000
# 487/487 [==============================] - 50s 102ms/step - loss: 7.8278e-08 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 0.9979
# Epoch 54/1000
# 487/487 [==============================] - 50s 102ms/step - loss: 7.1481e-08 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9976
# Epoch 55/1000
# 487/487 [==============================] - 50s 102ms/step - loss: 7.0957e-08 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9980
# Epoch 56/1000
# 487/487 [==============================] - 49s 101ms/step - loss: 7.0418e-08 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9978
# Epoch 57/1000
# 487/487 [==============================] - 49s 100ms/step - loss: 7.3679e-08 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 0.9978
# Epoch 58/1000
# 487/487 [==============================] - 49s 101ms/step - loss: 0.0271 - accuracy: 0.9929 - val_loss: 1.6577 - val_accuracy: 0.6404
# Epoch 59/1000
# 487/487 [==============================] - 50s 103ms/step - loss: 0.0073 - accuracy: 0.9984 - val_loss: 0.0178 - val_accuracy: 0.9957
# Epoch 60/1000
# 487/487 [==============================] - 50s 102ms/step - loss: 2.9373e-04 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 0.9969
# Epoch 61/1000
# 487/487 [==============================] - 50s 102ms/step - loss: 1.3917e-04 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9969
# Epoch 62/1000
# 487/487 [==============================] - 49s 102ms/step - loss: 9.6135e-05 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 0.9971
# Epoch 63/1000
# 487/487 [==============================] - 50s 102ms/step - loss: 7.1828e-05 - accuracy: 1.0000 - val_loss: 0.0107 - val_accuracy: 0.9972
# Epoch 64/1000
# 487/487 [==============================] - 49s 101ms/step - loss: 5.5572e-05 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 0.9973
# Epoch 65/1000
# 487/487 [==============================] - 50s 103ms/step - loss: 4.3673e-05 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9973

# %%
print('Saving')
np.save(load_path+model_name1+'_history.npy',history_const.history)
model1.save(load_path+model_name1+'_model.h5') 
print("saved")
# Out:
# Saving
# saved

# %%
# #load saved history
history_const=np.load(load_path+model_name1+'_history.npy',allow_pickle='TRUE').item()

# #load saved model
model1=load_model(load_path+model_name1+'_model.h5')

print("loaded")

# %%
print('Plots')
plt.plot(history_const.history['loss'])
plt.plot(history_const.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
# plt.savefig('F:/VA/onehandtwohand/26words_DSLR_results/'+model_name1+'_loss.png')
plt.savefig(load_path+model_name1+'_loss.png')
plt.show()
plt.plot(history_const.history['accuracy'])
plt.plot(history_const.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')

plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig(load_path+model_name1+'_accuracy.png')
plt.show()
# Out:
# Plots

# %%
print('Confusion matrix')
Y_pred = model1.predict(X_new)
y_pred = np.argmax(Y_pred, axis=1)
y_test1 = np.argmax(y_new, axis=1)

cm=metrics.confusion_matrix(y_test1, y_pred)


cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
a4_dims = (200, 100)
fig,ax= plt.subplots(figsize=a4_dims)
sns.heatmap(cm, annot=True, fmt=".2f", ax=ax,  linewidth=.5);  
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.set_xticklabels(CATEGORIES)
ax.set_yticklabels(CATEGORIES)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.setp(ax.get_xticklabels(), rotation=90, horizontalalignment='right')
plt.setp(ax.get_yticklabels(), rotation=0, horizontalalignment='right')
plt.savefig(load_path+model_name1+'_cm.png',bbox_inches='tight')
plt.show()

# %%
#PLot fractional incorrect misclassifications

incorr_fraction = 1 - np.diag(cm) / np.sum(cm, axis=1)

fig, ax = plt.subplots(figsize=(12,8))
plt.bar(np.arange(cat_len), incorr_fraction)
plt.xlabel('True Label')
plt.ylabel('Fraction of incorrect predictions')
plt.xticks(np.arange(cat_len), CATEGORIES)
plt.savefig(load_path+model_name1+'_incorrect_percentage.png',bbox_inches='tight')
plt.show()

# %%
#CHECK RANDOM IMAGES FROM TESTED DATA WHETHER RIGHT OR WRONG

i = random.randint(1,cat_len)
plt.imshow(X_new[i,:,:,2]) 
print("Predicted Label: ", CATEGORIES[int(y_pred[i])])
print("True Label: ", CATEGORIES[int(y_test1[i])])

# %% [markdown]
# # Colourful mediapipe testing with VA_create_3.0

# %%
import cv2
import mediapipe as mp
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results
    
def draw_landmarks(image, results):   
    #face
    mp_drawing.draw_landmarks(
        image,
        results.face_landmarks,
        mp_holistic.FACEMESH_CONTOURS,
        landmark_drawing_spec=None,
        connection_drawing_spec=mp_drawing_styles
        .get_default_face_mesh_contours_style())
#     #pose
#     mp_drawing.draw_landmarks(
#         image,
#         results.pose_landmarks,
#         mp_holistic.POSE_CONNECTIONS,
#         landmark_drawing_spec=mp_drawing_styles
#         .get_default_pose_landmarks_style())
    
    #left hand
    mp_drawing.draw_landmarks(
        image,
        results.left_hand_landmarks,
        mp_holistic.HAND_CONNECTIONS,
#         landmark_drawing_spec=None,
            mp_drawing_styles.get_default_hand_landmarks_style(),
            mp_drawing_styles.get_default_hand_connections_style())
    # right hand
    mp_drawing.draw_landmarks(
        image,
        results.right_hand_landmarks,
        mp_holistic.HAND_CONNECTIONS,
#         landmark_drawing_spec=None,
            mp_drawing_styles.get_default_hand_landmarks_style(),
            mp_drawing_styles.get_default_hand_connections_style())

# %%
## For veryyyyyyyy beautiful webcam input:

cap = cv2.VideoCapture(0)
org = (20, 20)  
org1 = (310, 20) 
fontScale = 0.65  
font = cv2.FONT_HERSHEY_SIMPLEX
# Blue color in BGR
color = (130, 0, 0)  
# Line thickness of 2 px
thickness = 1 
thickness1 = -1
start_point = (0,0)
end_point = (480,30)
color1 = (255, 255, 255)  
cls='crocodile'
with mp_holistic.Holistic(min_detection_confidence=0.5,min_tracking_confidence=0.5) as holistic:
      while cap.isOpened():
        #image from feeder
        r, img_array = cap.read()
        img_array = cv2.flip(img_array, 1)
        #webcam
        img_array = img_array[:, 80:560, :]
        #dslr
#         img_array = cv2.resize(img_array[:, 224:800, :],(480,480))
        
        image, results = mediapipe_detection(img_array, holistic)
        draw_landmarks(image, results)
        if not (results.left_hand_landmarks or results.right_hand_landmarks):
            continue

        # white background
        img = np.zeros([480,480,3],dtype=np.uint8)
        img.fill(255) 
        draw_landmarks(img, results)

        # for prediction
        IMG_SIZE=128
        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
        X = np.array(img).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
        X = X.astype('float32')
        X /= 255
        X = np.array(X)
        Y = model1.predict(X,verbose=0)

        if np.max(Y)>0.2:
            # for display
            image = cv2.rectangle(image, start_point, end_point, color1, thickness1)
            image = cv2.rectangle(image, (0,30), (480,30), color, 2)
            image = cv2.putText(image,"Prediction: "+ CATEGORIES[np.argmax(Y)], org, font, 
                   fontScale, color, thickness, cv2.LINE_AA)
            image = cv2.putText(image,"Accuracy: "+ "%.2f" % np.max(Y), org1, font, 
                   fontScale, color, thickness, cv2.LINE_AA)
            if CATEGORIES[np.argmax(Y)]==cls:
                cv2.imwrite(load_path+'/15layer_99.80_test_images/mp_'+
                            CATEGORIES[np.argmax(Y)]+'_'+str(np.max(Y))+'.jpg',image)
                cv2.imwrite(load_path+'/15layer_99.80_test_images/ori_'+
                            CATEGORIES[np.argmax(Y)]+'_'+str(np.max(Y))+'.jpg',img_array)


        cv2.imshow('Realtime testing', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
                break
# close the camera
cap.release()

# close all the opened windows
cv2.destroyAllWindows()
